# %% [markdown]
# <a href="https://colab.research.google.com/github/virajyadav/google_colab_experiments/blob/main/virtual_try_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Virtual Try-On
# This is a non-commercial educational project that uses [FrankMocap](https://github.com/facebookresearch/frankmocap) for pose estimation, [MultiGarmentNetwork](https://github.com/bharat-b7/MultiGarmentNetwork) for garment re-targeting. FrankMocap's [PyTorch3D](https://pytorch3d.org/) renderer was modified to support textures from MultiGarmentNetwork's garments.
#
# [Sample video](https://www.shutterstock.com/video/clip-15249886-talanted-young-dancer-man-dancing-breakdance-on) was taken from [shutterstock.com](https://www.shutterstock.com/)

# %%
rm -rf {,.[!.],..?}*

# %%
# !git clone --quiet -b virtual_try_on_demo https://github.com/pbelevich/frankmocap.git frankmocap

# %%
# !git clone --quiet -b delete_absolute_paths https://github.com/pbelevich/MultiGarmentNetwork.git MultiGarmentNetwork

# %%
# !mv frankmocap/* .

# %%
# !mv MultiGarmentNetwork/* .

# %%
# !rm -rf frankmocap MultiGarmentNetwork

# %% [markdown]
# Install dependencies

# %%
# !apt-get install -qq libboost-dev xvfb libosmesa6-dev
# Out:
# Selecting previously unselected package xvfb.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.9_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.9) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../libosmesa6_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libosmesa6:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../libosmesa6-dev_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.9) ...
# Setting up libosmesa6:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libosmesa6-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# ...

# %%
# !pip install -q -r docs/requirements.txt
# Out:
#      |████████████████████████████████| 542kB 7.1MB/s
#      |████████████████████████████████| 1.9MB 14.6MB/s
#      |████████████████████████████████| 133kB 51.5MB/s
#      |████████████████████████████████| 583kB 54.2MB/s
#      |████████████████████████████████| 51kB 8.4MB/s
# ...

# %%
# !pip install -q torchgeometry chumpy opendr
# Out:
#      |████████████████████████████████| 51kB 4.3MB/s

# %%
# !pip install 'git+https://github.com/facebookresearch/pytorch3d.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git to /tmp/pip-req-build-ngabo2u4
#   Running command git clone -q https://github.com/facebookresearch/pytorch3d.git /tmp/pip-req-build-ngabo2u4
# ...
#   Using cached fvcore-0.1.5.post20220119.tar.gz (55 kB)
# ...
#   Using cached iopath-0.1.9-py3-none-any.whl (27 kB)
# ...
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# ...
#   Using cached PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# ...
#   Using cached portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# ...
#   Created wheel for pytorch3d: filename=pytorch3d-0.6.1-cp37-cp37m-linux_x86_64.whl size=30647406 sha256=e6e98365bef20edd8fc68cb4a4268985ef754d3fad8e97c53f2b18f1b0027a8d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c_ev1fgn/wheels/db/2f/07/b84807ee4c9ffc917b90b716977d7fea8f9e841f6173150600
# ...

# %%
# !sh scripts/install_pose2d.sh
# !sh scripts/download_data_body_module.sh
# Out:
# Cloning into 'lightweight-human-pose-estimation.pytorch'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# Cloning into 'lightweight-human-pose-estimation.pytorch'...
# remote: Enumerating objects: 112, done.
# remote: Total 112 (delta 0), reused 0 (delta 0), pack-reused 112
# Receiving objects: 100% (112/112), 221.99 KiB | 18.50 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# --2022-02-09 06:59:51--  https://download.01.org/opencv/openvino_training_extensions/models/human_pose_estimation/checkpoint_iter_370000.pth
# Resolving download.01.org (download.01.org)... 104.106.178.195, 2600:1408:c400:395::4b21, 2600:1408:c400:391::4b21
# Connecting to download.01.org (download.01.org)|104.106.178.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87959810 (84M) [application/octet-stream]
# Saving to: ‘checkpoint_iter_370000.pth’
#
# ...

# %%
# !mkdir -p extra_data/smpl
# !test -f smplify_public_v2.zip || gdown --id 1BwNtKvArmUdy4Cpkx1seIlsHinopdaws
# !unzip -n -p mpips-smplify_public_v2.zip smplify_public/code/models/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl > extra_data/smpl/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BwNtKvArmUdy4Cpkx1seIlsHinopdaws
# To: /content/mpips-smplify_public_v2.zip
# 100% 53.0M/53.0M [00:01<00:00, 27.9MB/s]

# %%
# !test -f Multi-Garmentdataset.zip || wget -q -nc https://datasets.d2.mpi-inf.mpg.de/MultiGarmentNetwork/Multi-Garmentdataset.zip

# %%
# !test -d Multi-Garmentdataset || unzip -qn Multi-Garmentdataset.zip

# %%
# !mkdir -p assets
# !test -f mpips-smplify_public_v2.zip || gdown --id 1BwNtKvArmUdy4Cpkx1seIlsHinopdaws
# !test -f assets/neutral_smpl.pkl || unzip -n -p mpips-smplify_public_v2.zip smplify_public/code/models/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl > assets/neutral_smpl.pkl

# %% [markdown]
# Install [mesh](https://github.com/MPI-IS/mesh)

# %%
# !test -d mesh_dir || git clone --quiet https://github.com/pbelevich/mesh.git mesh_dir

# %%
# !cd mesh_dir && make all
# Out:
# ----- [ mesh_package ] Installing with the interpreter /usr/local/bin/python (version 3.7.12)
# ...
#      |████████████████████████████████| 1.1 MB 34.8 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 61.4 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 61.2 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 54.5 MB/s
# ...
#      |████████████████████████████████| 60.4 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 74.1 MB/s
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
# ...

# %% [markdown]
# Download sample source video

# %%
# !mkdir -p ./sample_data

# %%
# !pip install git+https://github.com/MPI-IS/mesh.git
# Out:
# ...
#   Cloning https://github.com/MPI-IS/mesh.git to /tmp/pip-req-build-7fheimek
#   Running command git clone -q https://github.com/MPI-IS/mesh.git /tmp/pip-req-build-7fheimek
# ...
#   Created wheel for psbody-mesh: filename=psbody_mesh-0.4-cp37-cp37m-linux_x86_64.whl size=1855225 sha256=9f19b2c954277d891267ea506a324ce519ddbff05e052161dd7cbd56b263d25c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eiaxm6ga/wheels/15/9e/8a/9a8acd7eb649a805222ec1acd1dad2abb02a333d74fb5c6afc
# Successfully built psbody-mesh
# ...

# %% [markdown]
# Run the demo

# %%
# !xvfb-run -a python -m demo.demo_bodymocap --input_path ./sample_data/male.mp4 --out_dir ./mocap_output --renderer_type pytorch3d
# Out:
# Loading Body Pose Estimator
# use_smplx False
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# --------------------------------------
# Visualization saved: ./mocap_output/rendered/00000.jpg
# Time: 12.25 sec/frame, FPS 0.08
# Processed : ./mocap_output/frames/00000.jpg
# --------------------------------------
# Visualization saved: ./mocap_output/rendered/00001.jpg
# Time: 11.50 sec/frame, FPS 0.09
# Processed : ./mocap_output/frames/00001.jpg
# --------------------------------------
# Visualization saved: ./mocap_output/rendered/00002.jpg
# Time: 11.67 sec/frame, FPS 0.09
# Processed : ./mocap_output/frames/00002.jpg
# --------------------------------------
# Visualization saved: ./mocap_output/rendered/00003.jpg
# Time: 11.65 sec/frame, FPS 0.09
# Processed : ./mocap_output/frames/00003.jpg
# --------------------------------------
# Visualization saved: ./mocap_output/rendered/00004.jpg
# Time: 11.62 sec/frame, FPS 0.09
# ...

# %%
# !rm -rf mocap_output

# %% [markdown]
# Show the result

# %%
# source: https://stackoverflow.com/a/65273831

from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = "./mocap_output/viraj.mp4"

# Compressed video path
compressed_path = "./mocap_output/viraj.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
